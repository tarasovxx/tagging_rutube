# %%
def get_flatten_iab_tags(csv_path: str) -> list[str]:
    iab_tags = list(map(str.strip, open(csv_path).readlines()[1:]))  # skip header
    flatten_tags = [
        ': '.join(map(str.strip, filter(bool, line.split(','))))  # split with ', ', strip and join with ': '
        for line in iab_tags
    ]
    return list(filter(bool, flatten_tags))  # filter empty strings

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from torch import nn
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import Trainer, TrainingArguments
import torch
from torch.utils.data import Dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
iab_tags = get_flatten_iab_tags('IAB_tags.csv')
iab_tags[:5]
# Out:
# ['Транспорт',
#  'Транспорт: Типы кузова автомобиля',
#  'Транспорт: Типы кузова автомобиля: Грузовой автомобиль',
#  'Транспорт: Типы кузова автомобиля: Седан',
#  'Транспорт: Типы кузова автомобиля: Универсал']

# %%
class VideoDataset(Dataset):
   def __init__(self, descriptions, tags, tokenizer, max_len):
	   self.descriptions = descriptions
		self.tags = tags
		self.tokenizer = tokenizer
		self.max_len = max_len
		self.max_tags = len(iab_tags)

	def __len__(self):
		return len(self.descriptions)

	def __getitem__(self, idx):
		description = str(self.descriptions[idx])
		tag = self.tags[idx]

		inputs = self.tokenizer(description, max_length=self.max_len, padding='max_length', truncation=True, return_tensors='pt')

		tag_tensor = np.zeros(self.max_tags)
		for t in tag:
			if t < self.max_tags:
				tag_tensor[t] = 1.0

		return {
			'input_ids': inputs['input_ids'].flatten(),
			'attention_mask': inputs['attention_mask'].flatten(),
			'labels': torch.tensor(tag_tensor, dtype=torch.float)
		}

# %%
class VideoTaggerModel(BertForSequenceClassification):
    def forward(self, input_ids, attention_mask=None, labels=None, **kwargs):
        outputs = super(VideoTaggerModel, self).forward(input_ids, attention_mask=attention_mask, **kwargs)
        logits = outputs.logits

        if labels is not None:
            loss_fct = nn.BCEWithLogitsLoss()
            loss = loss_fct(logits, labels)
            return loss, logits

        return logits

# %%
def split_tags(tags: str):
	splitted_tags = list(filter(bool, map(str.strip, str(tags).replace('  ', ' ').split(','))))
	return splitted_tags


df = pd.read_csv('train_data_categories.csv')
df['splitted_tags'] = df['tags'].apply(split_tags)
df.head()
# Out:
#                            video_id  \
# 0  9007f33c8347924ffa12f922da2a179d
# 1  9012707c45233bd601dead57bc9e2eca
# 2  e01d6ebabbc27e323fa1b7c581e9b96a
# 3  a00b145242be3ebc3b311455e94917af
# 4  b01a682bf4dfcc09f1e8fac5bc18785a
#
#                                                title  \
# 0  Пацанский клининг. Шоу «ЧистоТачка» | Повелите...
# 1  СarJitsu. 3 сезон, 6 серия. Нарек Симонян vs Ж...
# 2  Злые языки | Выпуск 1, Сезон 1 | Непорочность ...
# 3                 $1000 шоу | 1 выпуск | Автобоулинг
# 4                    В РОТ МНЕ НОТЫ #1 ВИТА ЧИКОВАНИ
#
#                                          description  \
# 0  Тяпа и Егор бросили вызов нестареющему «повели...
# 1  CarJitsu — бои в формате POP MMA, где вместо р...
# 2  Почему Дана Борисова предпочитает молчать о по...
# 3  В этом выпуске, популярный автоблогер Дима Гор...
# 4  В первом выпуске «В рот мне ноты» популярная п...
#
#                                                 tags  \
# 0                   Массовая культура: Юмор и сатира
# 1  События и достопримечательности:  Спортивные с...
# 2  Массовая культура: Отношения знаменитостей, Ма...
# 3     Транспорт, Спорт: Автогонки, Массовая культура
# 4                   Массовая культура: Юмор и сатира
#
#                                        splitted_tags
# 0                 [Массовая культура: Юмор и сатира]
# 1  [События и достопримечательности: Спортивные с...
# 2  [Массовая культура: Отношения знаменитостей, М...
# 3   [Транспорт, Спорт: Автогонки, Массовая культура]
# 4                 [Массовая культура: Юмор и сатира]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
max_len = 256

tags_encoder = {tag: idx for idx, tag in enumerate(iab_tags)}
df['encoded_tags'] = df['splitted_tags'].apply(
	lambda tags: np.array([tags_encoder.get(tag, 0) for tag in tags])
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
train_df, test_df = train_test_split(df, test_size=0.1)
train_dataset = VideoDataset(train_df['description'].values, train_df['encoded_tags'].tolist(), tokenizer, max_len)
test_dataset = VideoDataset(test_df['description'].values, test_df['encoded_tags'].tolist(), tokenizer, max_len)

# %%
model = VideoTaggerModel.from_pretrained('DeepPavlov/rubert-base-cased', num_labels=len(iab_tags))
for param in model.parameters():
    param.data = param.data.contiguous()

training_args = TrainingArguments(
   output_dir='./results',
   num_train_epochs=3,
   per_device_train_batch_size=16,
   per_device_eval_batch_size=16,
   warmup_steps=500,
   weight_decay=0.01,
   logging_dir='./logs'
)

trainer = Trainer(
   model=model,
   args=training_args,
   train_dataset=train_dataset,
   eval_dataset=test_dataset
)
# Out:
# Some weights of VideoTaggerModel were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='99' max='177' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 99/177 01:12 < 00:58, 1.34 it/s, Epoch 1.66/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='177' max='177' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [177/177 02:28, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=177, training_loss=0.5312618104751501, metrics={'train_runtime': 149.6781, 'train_samples_per_second': 18.921, 'train_steps_per_second': 1.183, 'total_flos': 374599083147264.0, 'train_loss': 0.5312618104751501, 'epoch': 3.0})

# %%
np_iab_tags = np.array(iab_tags)

# %%
def prepare_input(description, tokenizer, max_len):
    inputs = tokenizer(description, max_length=max_len, padding='max_length', truncation=True, return_tensors='pt')
    return inputs['input_ids'].to(device), inputs['attention_mask'].to(device)


def predict_tags(description, model, tokenizer, threshold=0.5, max_len=max_len):
    input_ids, attention_mask = prepare_input(description, tokenizer, max_len=max_len)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        if isinstance(outputs, torch.Tensor):
            logits = outputs
        else:
            logits = outputs.logits

    probabilities = torch.sigmoid(logits)
    predicted_tags = (probabilities > threshold).int()

    return np_iab_tags[predicted_tags.cpu().numpy().flatten() == 1]

# %%
predict_tags('Актёрское искусство. Как вести себя на кастинге. Ошибки молодых актёров.', model, tokenizer, threshold=0.43)
# Out:
# array(['Бизнес и финансы: Промышленность и сфера услуг: Энергетическая промышленность',
#        'Образование: Высшее образование',
#        'Массовая культура: Скандалы знаменитостей'], dtype='<U97')

# %%
def expand_tag(tag: str) -> list[str]:
    subtags = tag.split(': ')
    return [': '.join(subtags[:i]) for i in range(1, len(subtags) + 1)]

def count_iou(test_tags, predicted_tags):
    set1, set2 = set(), set()
    for tag in test_tags:
        set1.update(expand_tag(tag))
    for tag in predicted_tags:
        set2.update(expand_tag(tag))
    return float(len(set1 & set2) / len(set1 | set2))

# %%
expand_tag('Бизнес и финансы: Промышленность и сфера услуг: Энергетическая промышленность')
# Out:
# ['Бизнес и финансы',
#  'Бизнес и финансы: Промышленность и сфера услуг',
#  'Бизнес и финансы: Промышленность и сфера услуг: Энергетическая промышленность']

# %%
thresholds = 40, 45, 50

for th in thresholds:
    test_df[f'predicted_tags_{th}'] = test_df['description'].apply(lambda x: predict_tags(x, model, tokenizer, threshold=th / 100))
    test_df[f'iou_{th}'] = np.array([count_iou(x, y) for x, y in zip(test_df['splitted_tags'].values, test_df[f'predicted_tags_{th}'].values)])

test_df
# Out:
#                              video_id  \
# 137  e1fd71fc161933ac2bb9ad430f316d4d
# 701  aabedcb044b0c6b093e313377eeef77d
# 540  4858245da2dd61ddae497f48f66de214
# 547  e85d2af5f1b3b26a4618dda3223e4ef2
# 93   a13338b2adcbe3dbb441c5f6e0e3d7da
# ..                                ...
# 916  fdab98598407b22bdf49891fe3c02a60
# 24   305a910846f9d43507d2a2147510d4d7
# 273  7444a2ce14b3a95644df679b775e171a
# 228  4354a1ad8bf75f42466420f4b52dcbcd
# 61   80dec76cac626ae328461eb913ac5139
#
#                                                  title  \
# 137  МАКСИМ НАРОДНЫЙ Выпуск №13 ГОТОВИМ ЧАШУШУЛИ ПО...
# 701                    День с художником | Роман Казус
# 540  Такой расклад. Руны подскажут, как наладить ли...
# 547                                 Тру ДЕТЕКТОР I #13
# 93   100 главных русских изобретений | Выпуск 6| си...
# ..                                                 ...
# 916  TikTok Дайджест I 2 сезон, 5 выпуск I У Гаврил...
# 24                      Иордания. Сколько стоит отдых?
# 273    Антон Протеинов I #30 I Как всегда быть в форме
# 228              Артмеханика. Концерт группы Диктофон.
# 61   Артмеханика. Интервью. Илья Капустин и Яна Тру...
#
#                                            description  \
# 137  Предлагаю подписчикам приготовить чашушули по-...
# 701  В данном выпуске мы познакомим вас с творчеств...
# 540  Невероятно, но факт: руны знают всё. И даже ка...
# 547  Вы смотрите шоу с детектором лжи «Тру ДЕТЕКТОР...
# 93   Это открытие известно и в России, и в Голливуд...
# ..                                                 ...
# 916  Егор Крид спалил нос Амины! А у Юли Гаврилиной...
# 24   В этом выпуске Сашу Великолепного отправили от...
# 273  Антон Протеинов раскрыл секрет, как быть в фор...
# 228                           Концерт группы Диктофон.
# 61   Треш-арт! Откуда он появился и можно ли его пр...
#
#                                                   tags  \
# 137                           Еда и напитки: Кулинария
# 701  Хобби и интересы: Декоративно-прикладное искус...
# 540                   Религия и духовность: астрология
# 547                   Массовая культура: Юмор и сатира
# 93                            Массовая культура, Наука
# ..                                                 ...
# 916         Массовая культура: Отношения знаменитостей
# 24          Путешествия: Направления путешествий: Азия
# 273                   Массовая культура: Юмор и сатира
# 228  Массовая культура, Карьера, События и достопри...
# 61   Изобразительное искусство, Хобби и интересы: Д...
#
#                                          splitted_tags     encoded_tags  \
# 137                         [Еда и напитки: Кулинария]            [202]
# 701  [Хобби и интересы: Декоративно-прикладное иску...       [237, 112]
# 540                 [Религия и духовность: астрология]              [0]
# 547                 [Массовая культура: Юмор и сатира]            [406]
# 93                          [Массовая культура, Наука]       [398, 429]
# ..                                                 ...              ...
# 916       [Массовая культура: Отношения знаменитостей]            [403]
# 24        [Путешествия: Направления путешествий: Азия]            [570]
# 273                 [Массовая культура: Юмор и сатира]            [406]
# 228  [Массовая культура, Карьера, События и достопр...  [398, 112, 170]
# 61   [Изобразительное искусство, Хобби и интересы: ...       [187, 231]
#
#                                      predicted_tags_50  \
# 137  [Образование: Высшее образование, Массовая кул...
# 701  [Образование: Высшее образование, Массовая кул...
# 540                                                 []
# 547                                                 []
# 93                                                  []
# ..                                                 ...
# 916                                                 []
# 24                                                  []
# 273                  [Образование: Высшее образование]
# 228                  [Образование: Высшее образование]
# 61                                                  []
#
#                                      predicted_tags_45  iou_50    iou_45  \
# 137  [Бизнес и финансы: Промышленность и сфера услу...     0.0  0.000000
# 701  [Образование: Высшее образование, Массовая кул...     0.0  0.000000
# 540  [Бизнес и финансы: Промышленность и сфера услу...     0.0  0.000000
# 547  [Бизнес и финансы: Промышленность и сфера услу...     0.0  0.125000
# 93                   [Образование: Высшее образование]     0.0  0.000000
# ..                                                 ...     ...       ...
# 916  [Бизнес и финансы: Промышленность и сфера услу...     0.0  0.166667
# 24   [Бизнес и финансы: Промышленность и сфера услу...     0.0  0.000000
# 273  [Бизнес и финансы: Промышленность и сфера услу...     0.0  0.100000
# 228  [Бизнес и финансы: Промышленность и сфера услу...     0.0  0.125000
# 61                   [Образование: Высшее образование]     0.0  0.000000
#
#                                      predicted_tags_40    iou_40
# 137  [Транспорт: Типы автомобилей: Беспилотные авто...  0.000000
# 701  [Бизнес и финансы: Промышленность и сфера услу...  0.058824
# 540  [Бизнес и финансы: Бизнес: Стартапы, Бизнес и ...  0.000000
# 547  [Транспорт: Типы автомобилей: Подержанные авто...  0.076923
# 93   [Бизнес и финансы: Бизнес: Стартапы, Бизнес и ...  0.052632
# ..                                                 ...       ...
# 916  [Бизнес и финансы: Промышленность и сфера услу...  0.062500
# 24   [Бизнес и финансы: Промышленность и сфера услу...  0.000000
# 273  [Бизнес и финансы: Промышленность и сфера услу...  0.052632
# 228  [Бизнес и финансы: Промышленность и сфера услу...  0.100000
# 61   [Транспорт: Типы автомобилей: Прототипы автомо...  0.000000
#
# [105 rows x 12 columns]

# %%
test_df.to_csv('test.csv')

# %%
[test_df[f'iou_{th}'].mean() for th in thresholds]
# Out:
# [0.044988609184319045, 0.05252776324204895, 0.018412698412698412]
