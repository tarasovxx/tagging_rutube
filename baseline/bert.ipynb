# %% [markdown]
# # BERT-модель

# %% [markdown]
# ## Импорты библиотек

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from torch import nn
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import Trainer, TrainingArguments
import torch
from torch.utils.data import Dataset

# %% [markdown]
# Определяем, на чем будет идти обучение (gpu / cpu)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Класс датасета

# %%
class VideoDataset(Dataset):
	def __init__(self, descriptions, tags, tokenizer, max_len, max_tags):
		self.descriptions = descriptions
		self.tags = tags
		self.tokenizer = tokenizer
		self.max_len = max_len
		self.max_tags = max_tags

	def __len__(self):
		return len(self.descriptions)

	def __getitem__(self, idx):
		description = str(self.descriptions[idx])
		tag = self.tags[idx]

		inputs = self.tokenizer(description, max_length=self.max_len, padding='max_length', truncation=True, return_tensors='pt')

		# Вектор, где единица соответствует вхождению данного тега в множество
		tag_tensor = np.zeros(self.max_tags)
		for t in tag:
			if t < self.max_tags:
				tag_tensor[t] = 1.0

		return {
			'input_ids': inputs['input_ids'].flatten(),
			'attention_mask': inputs['attention_mask'].flatten(),
			'labels': torch.tensor(tag_tensor, dtype=torch.float)
		}

# %% [markdown]
# ## Модель классификатора
#
# Теги могут быть множественными, поэтому в качестве функции потерь хорошо подходит BCEWithLogitsLoss

# %%
class VideoTaggerModel(BertForSequenceClassification):
    def forward(self, input_ids, attention_mask=None, labels=None, **kwargs):
        outputs = super(VideoTaggerModel, self).forward(input_ids, attention_mask=attention_mask, **kwargs)
        logits = outputs.logits

        if labels is not None:
            loss_fct = nn.BCEWithLogitsLoss()
            loss = loss_fct(logits, labels)
            return loss, logits

        return logits

# %% [markdown]
# ## Вспомогательные функции для предобработки данных

# %%
# Предобработка подкатегории 
def cleanify_subtag(subtag):
    return subtag.strip().capitalize()


# Предобработка категории
def cleanify_tag(tag):
    return ': '.join(filter(bool, map(cleanify_subtag, tag.replace('  ', ' ').replace('\t', ':').split(':'))))


# Разбиваем строку на категории с предобработкой
def split_tags(tags):
    tags = str(tags)
    splitted_tags = list(filter(bool, map(cleanify_tag, tags.split(','))))
    return splitted_tags

# %%
df = pd.read_csv('train_data_categories.csv')
df
# Out:
#                               video_id  \
# 0     9007f33c8347924ffa12f922da2a179d
# 1     9012707c45233bd601dead57bc9e2eca
# 2     e01d6ebabbc27e323fa1b7c581e9b96a
# 3     a00b145242be3ebc3b311455e94917af
# 4     b01a682bf4dfcc09f1e8fac5bc18785a
# ...                                ...
# 1044  5fe16aa2869667bc1519e32a4c536b26
# 1045  4ffa5fbb2a410aa841659d8890ae5e3f
# 1046  3fc81df4bfe121ce2bc33dd581f5efeb
# 1047  efe0b4139ef82ec270b9e2fe0216214e
# 1048  fff1ef66d848bc8987ac5126f05b053b
#
#                                                   title  \
# 0     Пацанский клининг. Шоу «ЧистоТачка» | Повелите...
# 1     СarJitsu. 3 сезон, 6 серия. Нарек Симонян vs Ж...
# 2     Злые языки | Выпуск 1, Сезон 1 | Непорочность ...
# 3                    $1000 шоу | 1 выпуск | Автобоулинг
# 4                       В РОТ МНЕ НОТЫ #1 ВИТА ЧИКОВАНИ
# ...                                                 ...
# 1044  Злые языки | Выпуск 3, Сезон 1 | Эксклюзив Над...
# 1045  МАКСИМ НАРОДНЫЙ Выпуск №15 ГОТОВИМ «ПОХМЕЛЬНЫЙ...
# 1046  Роман Юнусов и блогерка Арина Ростовская пытаю...
# 1047  Артмеханика. Сезон 2. Выпуск 18. Современные р...
# 1048                     Артмеханика. Концерт Анет Сай.
#
#                                             description  \
# 0     Тяпа и Егор бросили вызов нестареющему «повели...
# 1     CarJitsu — бои в формате POP MMA, где вместо р...
# 2     Почему Дана Борисова предпочитает молчать о по...
# 3     В этом выпуске, популярный автоблогер Дима Гор...
# 4     В первом выпуске «В рот мне ноты» популярная п...
# ...                                                 ...
# 1044  Гость выпуска – Надин Серовски. Ей предстоит о...
# 1045  Предлагаю подписчикам быстро приготовить похме...
# 1046  В новом выпуске шоу «Спортивный Интерес» Рома ...
# 1047  “Артмеханика” представляет своих друзей! Поэты...
# 1048                     Артмеханика. Концерт Анет Сай.
#
#                                                    tags
# 0                      Массовая культура: Юмор и сатира
# 1     События и достопримечательности:  Спортивные с...
# 2     Массовая культура: Отношения знаменитостей, Ма...
# 3        Транспорт, Спорт: Автогонки, Массовая культура
# 4                      Массовая культура: Юмор и сатира
# ...                                                 ...
# 1044  Массовая культура:Отношения знаменитостей: Сем...
# 1045                           Еда и напитки: Кулинария
# 1046                                              Спорт
# 1047  Книги и литература: Поэзия, Музыка и аудио,  К...
# 1048                  Музыка и аудио:Современная музыка
#
# [1049 rows x 4 columns]

# %%
df['splitted_tags'] = df['tags'].apply(split_tags)
df
# Out:
#                               video_id  \
# 0     9007f33c8347924ffa12f922da2a179d
# 1     9012707c45233bd601dead57bc9e2eca
# 2     e01d6ebabbc27e323fa1b7c581e9b96a
# 3     a00b145242be3ebc3b311455e94917af
# 4     b01a682bf4dfcc09f1e8fac5bc18785a
# ...                                ...
# 1044  5fe16aa2869667bc1519e32a4c536b26
# 1045  4ffa5fbb2a410aa841659d8890ae5e3f
# 1046  3fc81df4bfe121ce2bc33dd581f5efeb
# 1047  efe0b4139ef82ec270b9e2fe0216214e
# 1048  fff1ef66d848bc8987ac5126f05b053b
#
#                                                   title  \
# 0     Пацанский клининг. Шоу «ЧистоТачка» | Повелите...
# 1     СarJitsu. 3 сезон, 6 серия. Нарек Симонян vs Ж...
# 2     Злые языки | Выпуск 1, Сезон 1 | Непорочность ...
# 3                    $1000 шоу | 1 выпуск | Автобоулинг
# 4                       В РОТ МНЕ НОТЫ #1 ВИТА ЧИКОВАНИ
# ...                                                 ...
# 1044  Злые языки | Выпуск 3, Сезон 1 | Эксклюзив Над...
# 1045  МАКСИМ НАРОДНЫЙ Выпуск №15 ГОТОВИМ «ПОХМЕЛЬНЫЙ...
# 1046  Роман Юнусов и блогерка Арина Ростовская пытаю...
# 1047  Артмеханика. Сезон 2. Выпуск 18. Современные р...
# 1048                     Артмеханика. Концерт Анет Сай.
#
#                                             description  \
# 0     Тяпа и Егор бросили вызов нестареющему «повели...
# 1     CarJitsu — бои в формате POP MMA, где вместо р...
# 2     Почему Дана Борисова предпочитает молчать о по...
# 3     В этом выпуске, популярный автоблогер Дима Гор...
# 4     В первом выпуске «В рот мне ноты» популярная п...
# ...                                                 ...
# 1044  Гость выпуска – Надин Серовски. Ей предстоит о...
# 1045  Предлагаю подписчикам быстро приготовить похме...
# 1046  В новом выпуске шоу «Спортивный Интерес» Рома ...
# 1047  “Артмеханика” представляет своих друзей! Поэты...
# 1048                     Артмеханика. Концерт Анет Сай.
#
#                                                    tags  \
# 0                      Массовая культура: Юмор и сатира
# 1     События и достопримечательности:  Спортивные с...
# 2     Массовая культура: Отношения знаменитостей, Ма...
# 3        Транспорт, Спорт: Автогонки, Массовая культура
# 4                      Массовая культура: Юмор и сатира
# ...                                                 ...
# 1044  Массовая культура:Отношения знаменитостей: Сем...
# 1045                           Еда и напитки: Кулинария
# 1046                                              Спорт
# 1047  Книги и литература: Поэзия, Музыка и аудио,  К...
# 1048                  Музыка и аудио:Современная музыка
#
#                                           splitted_tags
# 0                    [Массовая культура: Юмор и сатира]
# 1     [События и достопримечательности: Спортивные с...
# 2     [Массовая культура: Отношения знаменитостей, М...
# 3      [Транспорт, Спорт: Автогонки, Массовая культура]
# 4                    [Массовая культура: Юмор и сатира]
# ...                                                 ...
# 1044  [Массовая культура: Отношения знаменитостей: С...
# 1045                         [Еда и напитки: Кулинария]
# 1046                                            [Спорт]
# 1047  [Книги и литература: Поэзия, Музыка и аудио, К...
# 1048               [Музыка и аудио: Современная музыка]
#
# [1049 rows x 5 columns]

# %% [markdown]
# ## Находим уникальные теги
#
# На самом деле тегов больше 600, однако используется всего чуть больше 140. Сокращение количества возможных тегов позволяет повысить качество модели

# %%
unique_tags = set(sum(df['splitted_tags'].tolist(), []))
len(unique_tags)
# Out:
# 141

# %% [markdown]
# ## Немного аналитики
#
# Это позволяет нам понять, что, используя метрику, IoU на маленьких данных выгоднее угадывать только один уровень, так как математическое ожидание IoU с предсказанием второго уровня будет сильно меньше. Однако, верно предсказав второй уровень, мы можем с хорошей вероятностью предсказать и третий, что повысит метрику IoU

# %%
tags_by_levels = {}
for tag in unique_tags:
  subtags = list(map(str.strip, tag.split(':')))
  tags_by_levels.setdefault(subtags[0], {})
  if len(subtags) > 1:
    tags_by_levels[subtags[0]].setdefault(subtags[1], {})
  if len(subtags) > 2:
    tags_by_levels[subtags[0]][subtags[1]].setdefault(subtags[2], {})


print('Тегов первого уровня', len(tags_by_levels))
print('Среднее число тегов второго уровня', np.mean([len(v) for v in tags_by_levels.values()]))
print('Среднее число тегов третьего уровня', np.mean([len(v) for k in tags_by_levels.values() for v in k.values()]))
# Out:
# Тегов первого уровня 36
# Среднее число тегов второго уровня 2.7222222222222223
# Среднее число тегов третьего уровня 0.29591836734693877

# %% [markdown]
# ## Обрезаем тэги до первого уровня

# %%
def truncate_tag_to_first_level(tag):
  return str(tag).split(':')[0].strip()

def truncate_tags_to_first_level(tags):
  return list(set(map(truncate_tag_to_first_level, tags)))

# %%
df['truncated_splitted_tags'] = df['splitted_tags'].apply(truncate_tags_to_first_level)
df
# Out:
#                               video_id  \
# 0     9007f33c8347924ffa12f922da2a179d
# 1     9012707c45233bd601dead57bc9e2eca
# 2     e01d6ebabbc27e323fa1b7c581e9b96a
# 3     a00b145242be3ebc3b311455e94917af
# 4     b01a682bf4dfcc09f1e8fac5bc18785a
# ...                                ...
# 1044  5fe16aa2869667bc1519e32a4c536b26
# 1045  4ffa5fbb2a410aa841659d8890ae5e3f
# 1046  3fc81df4bfe121ce2bc33dd581f5efeb
# 1047  efe0b4139ef82ec270b9e2fe0216214e
# 1048  fff1ef66d848bc8987ac5126f05b053b
#
#                                                   title  \
# 0     Пацанский клининг. Шоу «ЧистоТачка» | Повелите...
# 1     СarJitsu. 3 сезон, 6 серия. Нарек Симонян vs Ж...
# 2     Злые языки | Выпуск 1, Сезон 1 | Непорочность ...
# 3                    $1000 шоу | 1 выпуск | Автобоулинг
# 4                       В РОТ МНЕ НОТЫ #1 ВИТА ЧИКОВАНИ
# ...                                                 ...
# 1044  Злые языки | Выпуск 3, Сезон 1 | Эксклюзив Над...
# 1045  МАКСИМ НАРОДНЫЙ Выпуск №15 ГОТОВИМ «ПОХМЕЛЬНЫЙ...
# 1046  Роман Юнусов и блогерка Арина Ростовская пытаю...
# 1047  Артмеханика. Сезон 2. Выпуск 18. Современные р...
# 1048                     Артмеханика. Концерт Анет Сай.
#
#                                             description  \
# 0     Тяпа и Егор бросили вызов нестареющему «повели...
# 1     CarJitsu — бои в формате POP MMA, где вместо р...
# 2     Почему Дана Борисова предпочитает молчать о по...
# 3     В этом выпуске, популярный автоблогер Дима Гор...
# 4     В первом выпуске «В рот мне ноты» популярная п...
# ...                                                 ...
# 1044  Гость выпуска – Надин Серовски. Ей предстоит о...
# 1045  Предлагаю подписчикам быстро приготовить похме...
# 1046  В новом выпуске шоу «Спортивный Интерес» Рома ...
# 1047  “Артмеханика” представляет своих друзей! Поэты...
# 1048                     Артмеханика. Концерт Анет Сай.
#
#                                                    tags  \
# 0                      Массовая культура: Юмор и сатира
# 1     События и достопримечательности:  Спортивные с...
# 2     Массовая культура: Отношения знаменитостей, Ма...
# 3        Транспорт, Спорт: Автогонки, Массовая культура
# 4                      Массовая культура: Юмор и сатира
# ...                                                 ...
# 1044  Массовая культура:Отношения знаменитостей: Сем...
# 1045                           Еда и напитки: Кулинария
# 1046                                              Спорт
# 1047  Книги и литература: Поэзия, Музыка и аудио,  К...
# 1048                  Музыка и аудио:Современная музыка
#
#                                           splitted_tags  \
# 0                    [Массовая культура: Юмор и сатира]
# 1     [События и достопримечательности: Спортивные с...
# 2     [Массовая культура: Отношения знаменитостей, М...
# 3      [Транспорт, Спорт: Автогонки, Массовая культура]
# 4                    [Массовая культура: Юмор и сатира]
# ...                                                 ...
# 1044  [Массовая культура: Отношения знаменитостей: С...
# 1045                         [Еда и напитки: Кулинария]
# 1046                                            [Спорт]
# 1047  [Книги и литература: Поэзия, Музыка и аудио, К...
# 1048               [Музыка и аудио: Современная музыка]
#
#                                 truncated_splitted_tags
# 0                                   [Массовая культура]
# 1     [События и достопримечательности, Массовая кул...
# 2                                   [Массовая культура]
# 3                 [Транспорт, Спорт, Массовая культура]
# 4                                   [Массовая культура]
# ...                                                 ...
# 1044                                [Массовая культура]
# 1045                                    [Еда и напитки]
# 1046                                            [Спорт]
# 1047      [Карьера, Книги и литература, Музыка и аудио]
# 1048                                   [Музыка и аудио]
#
# [1049 rows x 6 columns]

# %% [markdown]
# ## Получаем уникальные тэги первого уровня

# %%
unique_truncated_tags = set(map(truncate_tag_to_first_level, unique_tags))
unique_truncated_tags
# Out:
# {'Nan',
#  'Бизнес и финансы',
#  'Дом и сад',
#  'Еда и напитки',
#  'Здоровый образ жизни',
#  'Игры',
#  'Игры и головоломки',
#  'Изобразительное искусство',
#  'Информационные технологии',
#  'Карьера',
#  'Книги и литература',
#  'Компьютеры и цифровые технологии',
#  'Красота',
#  'Личные финансы',
#  'Массовая культура',
#  'Медицина',
#  'Медицинские направления',
#  'Музыка и аудио',
#  'Наука',
#  'Недвижимость',
#  'Новости и политика',
#  'Образование',
#  'Отношения знаменитостей',
#  'Путешествия',
#  'Религия и духовность',
#  'Семья и отношения',
#  'События и достопримечательности',
#  'Создание контента',
#  'Спорт',
#  'Стиль и красота',
#  'Телевидение',
#  'Транспорт',
#  'Фильмы и анимация',
#  'Хобби и интересы',
#  'Хобби и стиль',
#  'Экономика'}

# %%
iab_tags = list(unique_truncated_tags)
iab_tags
# Out:
# ['Спорт',
#  'Дом и сад',
#  'Изобразительное искусство',
#  'Игры и головоломки',
#  'Музыка и аудио',
#  'Наука',
#  'События и достопримечательности',
#  'Карьера',
#  'Хобби и стиль',
#  'Путешествия',
#  'Отношения знаменитостей',
#  'Хобби и интересы',
#  'Экономика',
#  'Красота',
#  'Семья и отношения',
#  'Nan',
#  'Создание контента',
#  'Книги и литература',
#  'Бизнес и финансы',
#  'Личные финансы',
#  'Здоровый образ жизни',
#  'Игры',
#  'Информационные технологии',
#  'Стиль и красота',
#  'Медицинские направления',
#  'Транспорт',
#  'Новости и политика',
#  'Телевидение',
#  'Медицина',
#  'Фильмы и анимация',
#  'Массовая культура',
#  'Образование',
#  'Еда и напитки',
#  'Недвижимость',
#  'Компьютеры и цифровые технологии',
#  'Религия и духовность']

# %% [markdown]
# ## Токенизация
#
# Кодируем тэги с помощью токенизатора DeepPavlov/rubert-base-cased, который показал лучший результат при работе с русским текстом

# %%
tokenizer = BertTokenizer.from_pretrained('DeepPavlov/rubert-base-cased')
max_len = 256

tags_encoder = {tag: idx for idx, tag in enumerate(iab_tags)}
df['encoded_tags'] = df['truncated_splitted_tags'].apply(
	lambda tags: np.array([tags_encoder[tag] for tag in tags])
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Разбиение датасета
#
# Обучаем на 90% данных, тестируем на 10%

# %%
train_df, test_df = train_test_split(df, test_size=0.1)
train_dataset = VideoDataset(train_df['description'].values, train_df['encoded_tags'].tolist(), tokenizer, max_len, len(iab_tags))
test_dataset = VideoDataset(test_df['description'].values, test_df['encoded_tags'].tolist(), tokenizer, max_len, len(iab_tags))

# %% [markdown]
# ## Модель
#
# Используем предобученную модель DeepPavlov/rubert-base-cased

# %%
model = VideoTaggerModel.from_pretrained('DeepPavlov/rubert-base-cased', num_labels=len(iab_tags))
for param in model.parameters():
    param.data = param.data.contiguous()

training_args = TrainingArguments(
   output_dir='./results',
   num_train_epochs=5,
   per_device_train_batch_size=16,
   per_device_eval_batch_size=16,
   warmup_steps=500,
   weight_decay=0.01,
   logging_dir='./logs'
)

trainer = Trainer(
   model=model,
   args=training_args,
   train_dataset=train_dataset,
   eval_dataset=test_dataset
)
# Out:
# Some weights of VideoTaggerModel were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Обучение
#
# 5 эпох заняло чуть менее 4 минут. С увеличением числа эпох точность повышается

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='295' max='295' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [295/295 03:45, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=295, training_loss=0.3310893947795286, metrics={'train_runtime': 228.3025, 'train_samples_per_second': 20.674, 'train_steps_per_second': 1.292, 'total_flos': 621131647057920.0, 'train_loss': 0.3310893947795286, 'epoch': 5.0})

# %% [markdown]
# ## Предсказание
#
# Кодируем описание, которое подается на вход и по вектору вероятностей определяем, какие теги будут на выходе, отсекая по заданному порогу

# %%
np_iab_tags = np.array(iab_tags)

def prepare_input(description, tokenizer, max_len):
    inputs = tokenizer(description, max_length=max_len, padding='max_length', truncation=True, return_tensors='pt')
    return inputs['input_ids'].to(device), inputs['attention_mask'].to(device)


def predict_tags(description, threshold=0.5, max_len=max_len):
    input_ids, attention_mask = prepare_input(description, tokenizer, max_len=max_len)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        if isinstance(outputs, torch.Tensor):
            logits = outputs
        else:
            logits = outputs.logits

    probabilities = torch.sigmoid(logits)
    predicted_tags = (probabilities > threshold).int()

    return np_iab_tags[predicted_tags.cpu().numpy().flatten() == 1]

# %%
predict_tags('Актёрское искусство. Как вести себя на кастинге. Ошибки молодых актёров.', threshold=0.43)
# Out:
# array(['Массовая культура'], dtype='<U32')

# %% [markdown]
# ## Расчёт метрики

# %%
def expand_tag(tag: str) -> list[str]:
    subtags = tag.split(': ')
    return [': '.join(subtags[:i]) for i in range(1, len(subtags) + 1)]

def count_iou(test_tags, predicted_tags):
    set1, set2 = set(), set()
    for tag in test_tags:
        set1.update(expand_tag(tag))
    for tag in predicted_tags:
        set2.update(expand_tag(tag))
    return float(len(set1 & set2) / len(set1 | set2))

# %%
expand_tag('Бизнес и финансы: Промышленность и сфера услуг: Энергетическая промышленность')
# Out:
# ['Бизнес и финансы',
#  'Бизнес и финансы: Промышленность и сфера услуг',
#  'Бизнес и финансы: Промышленность и сфера услуг: Энергетическая промышленность']

# %% [markdown]
# ### Подбор порогового значения
#
# Здесь мы подбираем теги, исходя из заданного порогового значения для их отсечения.
# Чем меньше порог, тем больше тегов (тем больше знаменатель в IoU).

# %%
thresholds = np.linspace(10., 50., num=9)

for th in thresholds:
    test_df[f'predicted_tags_{th}'] = test_df['description'].apply(lambda x: predict_tags(x, threshold=th / 100))
    test_df[f'iou_{th}'] = np.array([count_iou(x, y) for x, y in zip(test_df['splitted_tags'].values, test_df[f'predicted_tags_{th}'].values)])

test_df
# Out:
#                              video_id  \
# 483  b7b149c0dd4f9f5cea535af7e6bf95cd
# 640  ca39c17bde5cc48ce95a9a7fa5f733dc
# 223  136669ed3a76f12ee2dff41b17ddd954
# 29   106bd13b84f390cce9d369571604ab75
# 748  fb11e767bbc2c8fcce5ee783f4402d6a
# ..                                ...
# 163  4231958ed9fc366f35afb4babf70e2bf
# 497  4790fc6692c29d4a50433cde975512a0
# 6    f02fceb454008fe7907b47324569b845
# 69   50f947a71f1a3ea225a3af7b2ff45f86
# 59   50c6ac5b1962519d47dff843ac80023c
#
#                                                  title  \
# 483        Дуэль. Вспышки-малышки. Миногарова и Коваль
# 640  МузЛофт-Концерт | Юлия Савичева.  «Я могла сов...
# 223         Злые языки | Выпуск 7, Сезон 3 | Анита Цой
# 29   Punch Box. 4 сезон, 7 серия. Курич Александр v...
# 748  Yunan MotoTour в ГрандТуре «Байкальская миля 2...
# ..                                                 ...
# 163  На связующих | Юлианна Караулова | Как найти н...
# 497  МАКСИМ НАРОДНЫЙ Выпуск №4 «ГОТОВИМ НАИВКУСНЕЙШ...
# 6    Женсовет I Выпуск 6 I Мужчина в новой феминист...
# 69   Гейм разбор. Выпуск №5 - Cyberpunk 2077 - реак...
# 59       Байкальская Миля 2023\n5-й фестиваль скорости
#
#                                            description  \
# 483  Выпуск 5. Битва блогеров или блогерш или блоге...
# 640  Торговый эквайринг от ПСБ за 0,9%. Возмещение ...
# 223  На этом Анита Цой собаку съела: миллионы на ог...
# 29   Punch Box — бои в формате POP MMA где вместо р...
# 748  Команда Yunan MotoTour побывала на Красноярско...
# ..                                                 ...
# 163  На связующих - это шоу, в котором Кирилл Фокин...
# 497  Максим Народный предлагает подписчикам пригото...
# 6    Краткая инструкция по выживанию для мужчин в с...
# 69   В этом выпуске футуролог реагирует на Cyberpun...
# 59   С 7 по 11 марта на льду Байкала прошел Междуна...
#
#                                                   tags  \
# 483                   Массовая культура: Юмор и сатира
# 640                  Массовая культура, Музыка и аудио
# 223          Массовая культура: Скандалы знаменитостей
# 29                    Спорт: Борьба, Массовая культура
# 748  Путешествия, Транспорт, События и достопримеча...
# ..                                                 ...
# 163                   Массовая культура: Юмор и сатира
# 497                           Еда и напитки: Кулинария
# 6                                    Семья и отношения
# 69          Массовая культура, Игры: Компьютерные игры
# 59   Транспорт, Спорт: Автогонки, События и достопр...
#
#                                          splitted_tags  \
# 483                 [Массовая культура: Юмор и сатира]
# 640                [Массовая культура, Музыка и аудио]
# 223        [Массовая культура: Скандалы знаменитостей]
# 29                  [Спорт: Борьба, Массовая культура]
# 748  [Путешествия, Транспорт, События и достопримеч...
# ..                                                 ...
# 163                 [Массовая культура: Юмор и сатира]
# 497                         [Еда и напитки: Кулинария]
# 6                                  [Семья и отношения]
# 69        [Массовая культура, Игры: Компьютерные игры]
# 59   [Транспорт, Спорт: Автогонки, События и достоп...
#
#                                truncated_splitted_tags encoded_tags  \
# 483                                [Массовая культура]         [30]
# 640                [Музыка и аудио, Массовая культура]      [4, 30]
# 223                                [Массовая культура]         [30]
# 29                          [Спорт, Массовая культура]      [0, 30]
# 748  [Транспорт, Путешествия, События и достопримеч...   [25, 9, 6]
# ..                                                 ...          ...
# 163                                [Массовая культура]         [30]
# 497                                    [Еда и напитки]         [32]
# 6                                  [Семья и отношения]         [14]
# 69                           [Игры, Массовая культура]     [21, 30]
# 59   [Транспорт, События и достопримечательности, С...   [25, 6, 0]
#
#                                    predicted_tags_10.0  iou_10.0  \
# 483  [События и достопримечательности, Массовая кул...  0.333333
# 640  [События и достопримечательности, Карьера, Мас...  0.200000
# 223  [Спорт, События и достопримечательности, Карье...  0.200000
# 29   [Спорт, Музыка и аудио, События и достопримеча...  0.400000
# 748  [Спорт, События и достопримечательности, Карье...  0.125000
# ..                                                 ...       ...
# 163  [Спорт, События и достопримечательности, Карье...  0.200000
# 497  [Спорт, События и достопримечательности, Карье...  0.000000
# 6    [Спорт, События и достопримечательности, Карье...  0.000000
# 69   [События и достопримечательности, Массовая кул...  0.250000
# 59   [События и достопримечательности, Карьера, Мас...  0.125000
#
#      predicted_tags_20.0  ...  predicted_tags_50.0  iou_50.0  \
# 483  [Массовая культура]  ...                   []  0.000000
# 640  [Массовая культура]  ...  [Массовая культура]  0.500000
# 223  [Массовая культура]  ...  [Массовая культура]  0.500000
# 29   [Массовая культура]  ...  [Массовая культура]  0.333333
# 748  [Массовая культура]  ...                   []  0.000000
# ..                   ...  ...                  ...       ...
# 163  [Массовая культура]  ...  [Массовая культура]  0.500000
# 497  [Массовая культура]  ...  [Массовая культура]  0.000000
# 6    [Массовая культура]  ...                   []  0.000000
# 69   [Массовая культура]  ...  [Массовая культура]  0.333333
# 59   [Массовая культура]  ...                   []  0.000000
#
#                                    predicted_tags_15.0  iou_15.0  \
# 483  [События и достопримечательности, Массовая кул...  0.333333
# 640  [События и достопримечательности, Массовая кул...  0.333333
# 223                                [Массовая культура]  0.500000
# 29                                 [Массовая культура]  0.333333
# 748                                [Массовая культура]  0.000000
# ..                                                 ...       ...
# 163                                [Массовая культура]  0.500000
# 497                                [Массовая культура]  0.000000
# 6                                  [Массовая культура]  0.000000
# 69                                 [Массовая культура]  0.333333
# 59                                 [Массовая культура]  0.000000
#
#      predicted_tags_25.0  iou_25.0  predicted_tags_35.0  iou_35.0  \
# 483  [Массовая культура]  0.500000  [Массовая культура]  0.500000
# 640  [Массовая культура]  0.500000  [Массовая культура]  0.500000
# 223  [Массовая культура]  0.500000  [Массовая культура]  0.500000
# 29   [Массовая культура]  0.333333  [Массовая культура]  0.333333
# 748  [Массовая культура]  0.000000  [Массовая культура]  0.000000
# ..                   ...       ...                  ...       ...
# 163  [Массовая культура]  0.500000  [Массовая культура]  0.500000
# 497  [Массовая культура]  0.000000  [Массовая культура]  0.000000
# 6    [Массовая культура]  0.000000  [Массовая культура]  0.000000
# 69   [Массовая культура]  0.333333  [Массовая культура]  0.333333
# 59   [Массовая культура]  0.000000  [Массовая культура]  0.000000
#
#      predicted_tags_45.0  iou_45.0
# 483  [Массовая культура]  0.500000
# 640  [Массовая культура]  0.500000
# 223  [Массовая культура]  0.500000
# 29   [Массовая культура]  0.333333
# 748  [Массовая культура]  0.000000
# ..                   ...       ...
# 163  [Массовая культура]  0.500000
# 497  [Массовая культура]  0.000000
# 6    [Массовая культура]  0.000000
# 69   [Массовая культура]  0.333333
# 59   [Массовая культура]  0.000000
#
# [105 rows x 25 columns]

# %% [markdown]
# ## Результаты
#
# Как можно заметить, результаты для порогов 0.20-0.40 оказались одинаковыми. Это связано с небольшой обучающей выборкой

# %%
[(th, test_df[f'iou_{th}'].mean()) for th in thresholds]
# Out:
# [(10.0, 0.19255102040816324),
#  (15.0, 0.2514285714285714),
#  (20.0, 0.25396825396825395),
#  (25.0, 0.25396825396825395),
#  (30.0, 0.25396825396825395),
#  (35.0, 0.25396825396825395),
#  (40.0, 0.25396825396825395),
#  (45.0, 0.2515873015873016),
#  (50.0, 0.20476190476190476)]

# %% [markdown]
# ### Скорость работы
#
# Предсказание из 264 символов занимает 30 мс

# %%
# %time predict_tags('Нас заперли в огромном бункере и нам нужно выжить в нем 100 дней, чтобы получить миллион - 10 тысяч за каждый день! А чтобы нам было сложнее - нам устраивают разные челленджи и всячески пробуют помешать. Но мы выносливые и будем стараться изо всех сил! Ставь ЛАЙК!', threshold=0.4)
# Out:
# CPU times: user 28 ms, sys: 48 µs, total: 28.1 ms
# Wall time: 29.3 ms
# array(['Массовая культура'], dtype='<U32')

# %% [markdown]
# ## Сохранение результирующей выборки

# %%
test_df.to_csv('test.csv')

# %% [markdown]
# ## Сохранение модели

# %%
trainer.save_model('./model')

# %%
# !zip -r ./model.zip ./model
# Out:
#   adding: model/ (stored 0%)
#   adding: model/training_args.bin (deflated 51%)
#   adding: model/config.json (deflated 67%)
#   adding: model/model.safetensors (deflated 7%)
